# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#import module
import sys
sys.path[0] = 'C:/Users/z3414503/Documents/QTLab/qtlab_013/source/' 
import qt
d= qt.Data('C:/Users/z3414503/Desktop/Honours/Data/144815_C Spin Tail Bz = 1.5000/traces/C Spin Tail Bz = 1.5000_-0.02_trace.dat')

# %%
trace = []
time = []
signal = []
times = []
signals = []
traces = []

t1 = 0.1
t2 = 0.2
T = 0.35

#get traces from data file
import os
for file in os.listdir( "C:/Users/z3414503/Desktop/Honours/Data/144815_C Spin Tail Bz = 1.5000/traces" ):
    if file.endswith( ".dat" ):
        path = "C:/Users/z3414503/Desktop/Honours/Data/144815_C Spin Tail Bz = 1.5000/traces/"
        file = path + file
        d = qt.Data( file ) 
        x = d.get_data()
        trace, b, c = zip( *x )
        l = len( c ) / len( set( trace ) ) 
        l1 = t1 * l / T
        l2 = t2 * l / T
        for i in set( trace ): #split up the files into the seperate traces
            i = int( i )
            x = c[ ( i - 1 ) * l + int( l1 ) + 30: i * l + int( l1 ) + int( l2 ) - l - 30 ]
            y = b[ ( i - 1 ) * l + int( l1 ) + 30: i * l + int( l1 ) + int( l2 ) - l - 30 ] 
            signals.append( x )
            times.append( y )
            traces.append( trace[ i ] )

# %%
plot( times[300], signals[300] ) #test plot

# %%
#for some reason the outputs for these traces are in volts
#where as my simulations were done in amperes
V_t_max = 0.3
V_t = linspace( 0, V_t_max, 100 )

# %%
#plot histogram of the peak voltages of each trace
signals_down = []
signals_up = []
bars = 50
V_t = 0.15
for x in signals:
    #print max( x ) 
    if max( x ) >= V_t:
        #print "up"
        signals_up.append( max( x ) )
    if max( x ) < V_t:
        #print "down"
        signals_down.append( max( x ) )
plt.hist( signals_down, bars, histtype = 'step', normed = True, color = 'r' )
plt.hist( signals_up, bars, histtype = 'step', normed = True, color = 'b' )
# Out:
# (array([ 10.27620923,  20.55241846,   5.13810461,   0.        ,
#           0.        ,   0.        ,  10.27620923,   5.13810461,
#           5.13810461,   5.13810461,   0.        ,   5.13810461,
#           5.13810461,  20.55241846,  15.41431384,   0.        ,
#          20.55241846,   5.13810461,  25.69052307,  30.82862769,
#          20.55241846,   5.13810461,   0.        ,  20.55241846,
#           0.        ,  15.41431384,  35.9667323 ,  30.82862769,
#          10.27620923,  10.27620923,  10.27620923,  25.69052307,
#           5.13810461,  25.69052307,  56.51915076,  25.69052307,
#          20.55241846,  35.9667323 ,  15.41431384,  10.27620923,
#           5.13810461,   5.13810461,  15.41431384,  10.27620923,
#           5.13810461,   0.        ,  10.27620923,   0.        ,
#           0.        ,  10.27620923]),
#  array([ 0.15271733,  0.15429964,  0.15588195,  0.15746426,  0.15904657,
#          0.16062888,  0.1622112 ,  0.16379351,  0.16537582,  0.16695813,
#          0.16854044,  0.17012275,  0.17170506,  0.17328737,  0.17486969,
#          0.176452  ,  0.17803431,  0.17961662,  0.18119893,  0.18278124,
#          0.18436355,  0.18594587,  0.18752818,  0.18911049,  0.1906928 ,
#          0.19227511,  0.19385742,  0.19543973,  0.19702205,  0.19860436,
#          0.20018667,  0.20176898,  0.20335129,  0.2049336 ,  0.20651591,
#          0.20809822,  0.20968054,  0.21126285,  0.21284516,  0.21442747,
#          0.21600978,  0.21759209,  0.2191744 ,  0.22075672,  0.22233903,
#          0.22392134,  0.22550365,  0.22708596,  0.22866827,  0.23025058,
#          0.2318329 ]),
#  <a list of 1 Patch objects>)

# %%
V_t = 0.12

# %%
#define function to generate the histograms with respect to the voltage threshold
def hist( S ):
    signals_down = []
    signals_up = []
    bars = 50
    V = V_t
    up = 0
    down = 0
    for x in S:
        if max( x ) >= V:
            signals_up.append( max( x ) )
            up += 1
        if max( x ) < V:
            signals_down.append( max( x ) )
            down += 1
    values_d, bins_d, _ = plt.hist( signals_down, bars, histtype = 'step', normed = True, color = 'r' )
    values_u, bins_u, _ = plt.hist( signals_up, bars, histtype = 'step', normed = True, color = 'b' )
    print up
    print down
    return values_d, bins_d, values_u, bins_u

# %%
values_d, bins_d, values_u, bins_u = hist( signals )
# Out:
# 130
# 221

# %%
area_d = sum( numpy.diff( bins_d[ : ] ) * values_d[ : ] )
area_u = sum( numpy.diff( bins_u[ : ] ) * values_u[ : ] )

print area_d
print area_u
# Out:
# 1.0
# 1.0

# %%
#plot the visibility for a range of current thresholds
V_t_max = 0.3 #Volts
V_t = linspace( 0, V_t_max, 100 )
Vis = []
F0 = []
F1 = []
for x in V_t:
    idx_d = min(range(len(bins_d)), key=lambda i: abs(bins_d[i]-x))
    idx_u = min(range(len(bins_u)), key=lambda i: abs(bins_u[i]-x))
    F_0 = 1 - sum( numpy.diff( bins_u[ :idx_u + 1 ] ) * values_u[ :idx_u ] )
    F_1 = 1 - sum( numpy.diff( bins_d[ idx_d: ] ) * values_d[ idx_d: ] )
    Vis.append( (F_0 + F_1) - 1 )
    F0.append( F_0 )
    F1.append( F_1 )
figure()
plot( V_t, Vis, V_t, F0, V_t, F1 )
ylabel( 'Visibility ($\%$)', fontsize = 20 )
xlabel( '$V_t (V)$', fontsize = 20 )
Vis_max = max( Vis )
print Vis_max * 100
idx = Vis.index( Vis_max )
print V_t[idx]
# Out:
# 100.0
# 0.118181818182

# %%
import bisect
blips = []
V = 0.118
t_up = []
t_down = []
for x in signals:
    if max( x ) >= V:
        blips.append( x )
for x in blips:
    for i in x:
        if i > V:
            idx1 = x.index( i )
            t_up.append( idx1 )
            for j in x[ idx1: ]:
                if j < V:
                    idx2 = x.index( j )
                    t_down.append( idx2 )
                    break
            break
figure()
values_u, bins_u, _ = plt.hist(t_up, 200 , histtype = 'bar', normed = False)
figure()
values_d, bins_d, _ = plt.hist(t_down, 200 , histtype = 'bar', normed = False)
