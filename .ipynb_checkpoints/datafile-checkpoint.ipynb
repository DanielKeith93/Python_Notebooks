# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d=qt.Data()

# %%
import sys
sys.path[0:0] = 'C:/Users/z3414503/Documents/QTLab/qtlab_013/source/' 
import qt

# %%
d= qt.Data('C:/Users/z3414503/Desktop/Honours/Data/144815_C Spin Tail Bz = 1.5000/traces/C Spin Tail Bz = 1.5000_-0.02_trace.dat')

# %%
d
# Out:
# Data 'data2', filename 'C Spin Tail Bz = 1.5000_-0.02_trace.dat'

# %%
d.get_coordinates()
# Out:
# [{'end': 9.0,
#   'name': 'trace (#)',
#   'size': 9,
#   'start': 1.0,
#   'type': 'coordinate'},
#  {'end': 0.34981399522399997,
#   'name': 'time (S)',
#   'size': 3240,
#   'start': -1.3877787800000001e-17,
#   'type': 'coordinate'}]

# %%
d.get_dimensions()
# Out:
# [{'end': 9.0,
#   'name': 'trace (#)',
#   'size': 9,
#   'start': 1.0,
#   'type': 'coordinate'},
#  {'end': 0.34981399522399997,
#   'name': 'time (S)',
#   'size': 3240,
#   'start': -1.3877787800000001e-17,
#   'type': 'coordinate'},
#  {'name': 'value (V)', 'type': 'value'}]

# %%
x=d.get_data()

# %%
trace, time, signal = zip( *x )

# %% [raw]
# print X

# %%
print Y[0:3240]
# Out:
# (-1.3877787800000001e-17, 0.000108000616, 0.000216001232, 0.000324001848, 0.000432002464, 0.00054000307999999995, 0.00064800369600000001, 0.00075600431199999995, 0.00086400492800000001, 0.00097200554399999996, 0.0010800061599999999, 0.0011880067760000001, 0.001296007392, 0.001404008008, 0.0015120086239999999, 0.0016200092400000001, 0.001728009856, 0.001836010472, 0.0019440110879999999, 0.0020520117040000001, 0.0021600123199999998, 0.002268012936, 0.0023760135520000001, 0.0024840141679999999, 0.002592014784, 0.0027000154000000002, 0.0028080160159999999, 0.0029160166320000001, 0.0030240172479999998, 0.003132017864, 0.0032400184800000001, 0.0033480190959999999, 0.003456019712, 0.0035640203280000002, 0.0036720209439999999, 0.0037800215600000001, 0.0038880221759999998, 0.0039960227920000004, 0.0041040234080000002, 0.0042120240239999999, 0.0043200246399999996, 0.0044280252560000002, 0.0045360258719999999, 0.0046440264879999997, 0.0047520271040000003, 0.00486002772, 0.0049680283359999997, 0
# ...

# %%
plot( time[0:3240], signal[0:3240] )

# %%
def plot_trace( trace_number ):
    plot( time[ ( trace_number - 1 ) * 3240 : trace_number * 3240 ], signal[ ( trace_number - 1 ) * 3240 : trace_number * 3240 ] )
    return

# %%
plot_trace( 1 )

# %%
plot_trace( 2 )

# %%
plot_trace( 3 )

# %%
plot_trace(4)

# %%
plot_trace(5)

# %%
plot_trace(6)

# %%
plot_trace(7)

# %%
plot_trace(8)

# %%
plot_trace(9)

# %%
plot_trace(10)
