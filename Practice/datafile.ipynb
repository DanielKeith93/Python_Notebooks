# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d=qt.Data()

# %%
import sys
sys.path[0] = 'C:/Users/z3414503/Documents/QTLab/qtlab_013/source/' 
import qt

# %%
d= qt.Data('C:/Users/z3414503/Desktop/Honours/Data/144815_C Spin Tail Bz = 1.5000/traces/C Spin Tail Bz = 1.5000_-0.02_trace.dat')

# %%
d
# Out:
# Data 'data1', filename 'C Spin Tail Bz = 1.5000_-0.02_trace.dat'

# %%
d.get_coordinates()
# Out:
# [{'end': 9.0,
#   'name': 'trace (#)',
#   'size': 9,
#   'start': 1.0,
#   'type': 'coordinate'},
#  {'end': 0.34981399522399997,
#   'name': 'time (S)',
#   'size': 3240,
#   'start': -1.3877787800000001e-17,
#   'type': 'coordinate'}]

# %%
d.get_dimensions()
# Out:
# [{'end': 9.0,
#   'name': 'trace (#)',
#   'size': 9,
#   'start': 1.0,
#   'type': 'coordinate'},
#  {'end': 0.34981399522399997,
#   'name': 'time (S)',
#   'size': 3240,
#   'start': -1.3877787800000001e-17,
#   'type': 'coordinate'},
#  {'name': 'value (V)', 'type': 'value'}]

# %%
x=d.get_data()

# %%
trace, time, signal = zip( *x )

# %%
plot( time[0:3240], signal[0:3240] )

# %%
def plot_trace( trace_number ):
    plot( time[ ( trace_number - 1 ) * 3240 : trace_number * 3240 ], signal[ ( trace_number - 1 ) * 3240 : trace_number * 3240 ] )
    return

# %%
plot_trace( 1 )

# %%
plot_trace( 2 )

# %%
plot_trace( 3 )

# %%
plot_trace(4)

# %%
plot_trace(5)

# %%
plot_trace(6)

# %%
plot_trace(7)

# %%
plot_trace(8)

# %%
plot_trace(9)

# %%
print 0.1 * 3240 / 0.35
print 0.3 * 3240 / 0.35
# Out:
# 925.714285714
# 2777.14285714

# %%
plot( time[940:2781], signal[940:2781] )

# %%
signal1 = signal[ 0: 3240 ]
idx = signal1.index( max( signal1 ) )
print idx
signal1 = signal[ idx + 14: 3240 ]
idx = signal1.index( max( signal1 ) )
print idx
# Out:
# 929
# 1839

# %%
plot( time[ 948 + 2 * 3240 : 2781 + 2 * 3240 ], signal[ 948 + 2 * 3240 : 2781 + 2 * 3240 ] )
