# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import signal

# %%
from scipy import signal
import matplotlib.pyplot as plt
t = np.linspace(-1, 1, 200, endpoint=False)
sig  = np.cos(2 * np.pi * 7 * t) + signal.gausspulse(t - 0.4, fc=2)
widths = np.arange(1, 31)
cwtmatr = signal.cwt(sig, signal.ricker, widths)
plt.imshow(cwtmatr, extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto', vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())
plt.show()

# %%
plot( t, sig )

# %%
#define parameters
fs = 20000.0
lowcut = 10000.0
T = 0.055
nsamples = T * fs
N_0 = 0.55
N_1 = 1 - N_0
deltat = T #s, taken from spin to charge optimisation
t_down_in = 0.0051
t_up_out = 0.0065 #Taken from experimental data.
deltaI = 0.45 * 10 ** - 9 #A
points = nsamples
time1 = linspace( 0, deltat, points )
a_n = 2.4 * 10 ** - 12 #A / ( ( Hz ) ^ ( 1 / 2 ) ) #Have to multiply spectral density by a bandwidth.
f_c = lowcut #Hz, cut off frequency, also used as the bandwidth
A_n = a_n * sqrt( fs )
bars = 200
traces = 10000

# %%
from scipy.signal import bessel, lfilter


def bessel_lowpass(lowcut,fs, order=8):
    nyq = 0.5 * fs
    low = lowcut / nyq
    b, a = bessel(order, low, btype='low')
    return b, a


def bessel_lowpass_filter(data, lowcut,fs, order=8):
    b, a = bessel_lowpass(lowcut,fs, order=order)
    y = lfilter(b, a, data)
    return y

def sqr_pulse( c, time_arr, t1, t2, I ):
    start = int( ( t1 / deltat ) * len(time_arr) )
    finish = int( ( ( t1 + t2 ) / deltat ) * len(time_arr) )
    if c == 0:
        wave = time_arr[ : ] * 0
        wave[ start: finish ] =  ( time_arr[ start: finish ] * 0 ) + I 
        return wave
    elif c == 1:
        wave = time_arr[ : ] * 0
        return wave

# %%
y = bessel_lowpass_filter(sqr_pulse( 0, time1, t_up_out, t_down_in, deltaI ) + A_n * random.normal( 0, 1, points ), lowcut,fs, order=8)

# %%
plot( time1, y )

# %%
t = np.linspace(-1, 1, 200, endpoint=False)
sig  = y
widths = np.arange(1, 100)
cwtmatr = signal.cwt(sig, signal.ricker, widths)
plt.imshow(cwtmatr, extent=[0, 0.055, 1, 100], cmap='PRGn', aspect='auto', vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())
plt.show()

# %%
plot( time1, cwtmatr[10] )
plot( time1, cwtmatr[20] )
plot( time1, cwtmatr[30] )
plot( time1, cwtmatr[40] )
figure()
plot( time1, cwtmatr[0] )

# %%
print cwtmatr
print len( cwtmatr )
print len( cwtmatr[0])
# Out:
# [[  2.52158591e-10   5.14432724e-10  -2.36698427e-10 ...,   9.16850650e-11
#     2.56025044e-10  -7.34625550e-11]
#  [  2.96751675e-10   1.30173194e-10  -2.57998070e-10 ...,   2.14287623e-11
#     1.65024936e-10   1.62656088e-10]
#  [  4.45013943e-11  -5.14447073e-11  -1.49960069e-10 ...,  -9.78524355e-11
#     3.61335557e-11   1.29214690e-10]
#  ...,
#  [ -1.35034374e-11  -2.34438806e-11  -3.40867347e-11 ...,  -3.07521843e-10
#    -3.15329462e-10  -3.22437812e-10]
#  [ -4.79585898e-11  -5.91612876e-11  -7.10726762e-11 ...,  -2.91228736e-10
#    -2.99304370e-10  -3.06724963e-10]
#  [ -8.48789735e-11  -9.73213460e-11  -1.10465707e-10 ...,  -2.75302809e-10
#    -2.83586207e-10  -2.91251051e-10]]
# 49
# 1100

# %%
#checkout OpenCV for canny edge detection to use on the wavelet transform

# %%
from scipy import signal
xs = np.arange(0, np.pi, 0.05 )
data = np.sin(xs)
peakind = signal.find_peaks_cwt(data, np.arange(1,10))
peakind, xs[peakind], data[peakind]
# Out:
# ([32], array([ 1.6]), array([ 0.9995736]))

# %%
plot( xs, data )

# %%
data = bessel_lowpass_filter(sqr_pulse( 0, time1, t_up_out, t_down_in, deltaI ) + A_n * random.normal( 0, 1, points ), lowcut,fs, order=8)
peakind = signal.find_peaks_cwt(data, np.arange(1,10))
peakind, time1[peakind], data[peakind]
# Out:
# ([22,
#   26,
#   44,
#   57,
#   81,
#   103,
#   117,
#   122,
#   139,
#   177,
#   202,
#   226,
#   241,
#   249,
#   279,
#   280,
#   300,
#   313,
#   330,
#   364,
#   429,
#   434,
#   463,
#   493,
#   507,
#   530,
#   552,
#   560,
#   581,
#   598,
#   625,
#   651,
#   667,
#   682,
#   743,
#   744,
#   865,
#   880,
#   890,
#   906,
#   926,
#   944,
#   952,
#   974,
#   996,
#   1001,
#   1021,
#   1039,
#   1062,
#   1078],
#  array([ 0.001101  ,  0.00130118,  0.002202  ,  0.00285259,  0.00405369,
#          0.00515469,  0.00585532,  0.00610555,  0.00695632,  0.00885805,
#          0.01010919,  0.01131028,  0.01206096,  0.01246133,  0.01396269,
#          0.01401274,  0.01501365,  0.01566424,  0.01651501,  0.01821656,
#          0.02146952,  0.02171975,  0.02317106,  0.02467243,  0.02537307,
#          0.02652411,  0.02762511,  0.02802548,  0.02907643,  0.02992721,
#          0.03127843,  0.03257962,  0.03338035,  0.03413103,  0.0371838 ,
#          0.03723385,  0.04328935,  0.04404004,  0.04454049,  0.04534122,
#          0.04634213,  0.04724295,  0.04764331,  0.04874431,  0.04984531,
#          0.05009554,  0.05109645,  0.05199727,  0.05314832,  0.05394904]),
#  array([  1.05035520e-09,  -8.52961618e-11,   5.08499805e-10,
#           7.65542537e-10,   7.79045252e-12,  -1.20391094e-10,
#          -4.61882357e-11,   2.52995245e-10,   3.78540446e-10,
#           1.24674088e-09,   1.25970199e-09,   1.14088692e-09,
#           1.91961702e-10,   2.64455017e-10,   5.57848872e-10,
#           1.70011707e-10,   5.20116758e-10,   2.88081614e-10,
#           1.60173285e-10,   9.59090142e-10,   1.09212225e-10,
#           4.27758747e-10,   8.98477703e-10,   2.09225532e-10,
#           2.77245223e-10,   4.22998658e-10,   6.44262732e-10,
#           2.56974550e-10,  -8.12259466e-13,  -1.00690495e-10,
#           5.74199422e-11,  -1.86849781e-10,   2.39604634e-10,
#           3.08944428e-10,   3.65580123e-10,   3.70091415e-10,
#          -3.44782206e-10,   7.54786438e-11,   2.23900538e-10,
#           1.34995984e-10,   2.30273579e-10,   5.86245492e-10,
#           3.01866712e-10,   9.98938199e-11,   2.78593080e-10,
#          -2.19437334e-10,   5.24035440e-10,   4.93813647e-10,
#           4.47121153e-10,   2.35346906e-10]))

# %%
plot( time1[peakind], data[peakind] )
plot ( time1, data )

# %%
import scipy.ndimage as ndi
import scipy
import numpy
import Image
import math
sigma = 1.4
f = 'C:/Users/z3414503/Desktop/lion.jpg'
img = Image.open(f).convert('L') #grayscale
imgdata = numpy.array(img, dtype = float)
G = ndi.filters.gaussian_filter(imgdata, sigma)
sobelout = Image.new('L', img.size)                                       #empty image
gradx = numpy.array(sobelout, dtype = float)                        
grady = numpy.array(sobelout, dtype = float)
 
sobel_x = [[-1,0,1],
           [-2,0,2],
           [-1,0,1]]
sobel_y = [[-1,-2,-1],
           [0,0,0],
           [1,2,1]]
 
width = img.size[1]
height = img.size[0]
 
for x in range(1, width-1):
    for y in range(1, height-1):
        px = (sobel_x[0][0] * G[x-1][y-1]) + (sobel_x[0][1] * G[x][y-1]) + \
             (sobel_x[0][2] * G[x+1][y-1]) + (sobel_x[1][0] * G[x-1][y]) + \
             (sobel_x[1][1] * G[x][y]) + (sobel_x[1][2] * G[x+1][y]) + \
             (sobel_x[2][0] * G[x-1][y+1]) + (sobel_x[2][1] * G[x][y+1]) + \
             (sobel_x[2][2] * G[x+1][y+1])
 
        py = (sobel_y[0][0] * G[x-1][y-1]) + (sobel_y[0][1] * G[x][y-1]) + \
             (sobel_y[0][2] * G[x+1][y-1]) + (sobel_y[1][0] * G[x-1][y]) + \
             (sobel_y[1][1] * G[x][y]) + (sobel_y[1][2] * G[x+1][y]) + \
             (sobel_y[2][0] * G[x-1][y+1]) + (sobel_y[2][1] * G[x][y+1]) + \
             (sobel_y[2][2] * G[x+1][y+1])
        gradx[x][y] = px
        grady[x][y] = py
sobeloutmag = scipy.hypot(gradx, grady)
sobeloutdir = scipy.arctan2(grady, gradx)
for x in range(width):
    for y in range(height):
        if (sobeloutdir[x][y]<22.5 and sobeloutdir[x][y]>=0) or \
           (sobeloutdir[x][y]>=157.5 and sobeloutdir[x][y]<202.5) or \
           (sobeloutdir[x][y]>=337.5 and sobeloutdir[x][y]<=360):
            sobeloutdir[x][y]=0
        elif (sobeloutdir[x][y]>=22.5 and sobeloutdir[x][y]<67.5) or \
             (sobeloutdir[x][y]>=202.5 and sobeloutdir[x][y]<247.5):
            sobeloutdir[x][y]=45
        elif (sobeloutdir[x][y]>=67.5 and sobeloutdir[x][y]<112.5)or \
             (sobeloutdir[x][y]>=247.5 and sobeloutdir[x][y]<292.5):
            sobeloutdir[x][y]=90
        else:
            sobeloutdir[x][y]=135
mag_sup = sobeloutmag
for x in range(1, width-1):
    for y in range(1, height-1):
        if sobeloutdir[x][y]==0:
            if (sobeloutmag[x][y]<=sobeloutmag[x][y+1]) or \
               (sobeloutmag[x][y]<=sobeloutmag[x][y-1]):
                mag_sup[x][y]=0
        elif sobeloutdir[x][y]==45:
            if (sobeloutmag[x][y]<=sobeloutmag[x-1][y+1]) or \
               (sobeloutmag[x][y]<=sobeloutmag[x+1][y-1]):
                mag_sup[x][y]=0
        elif sobeloutdir[x][y]==90:
            if (sobeloutmag[x][y]<=sobeloutmag[x+1][y]) or \
               (sobeloutmag[x][y]<=sobeloutmag[x-1][y]):
                mag_sup[x][y]=0
        else:
            if (sobeloutmag[x][y]<=sobeloutmag[x+1][y+1]) or \
               (sobeloutmag[x][y]<=sobeloutmag[x-1][y-1]):
                mag_sup[x][y]=0
m = numpy.max(mag_sup)
th = 0.2*m
tl = 0.1*m
 
 
gnh = numpy.zeros((width, height))
gnl = numpy.zeros((width, height))
 
for x in range(width):
    for y in range(height):
        if mag_sup[x][y]>=th:
            gnh[x][y]=mag_sup[x][y]
        if mag_sup[x][y]>=tl:
            gnl[x][y]=mag_sup[x][y]
gnl = gnl-gnh
 
def traverse(i, j):
    x = [-1, 0, 1, -1, 1, -1, 0, 1]
    y = [-1, -1, -1, 0, 0, 1, 1, 1]
    for k in range(8):
        if gnh[i+x[k]][j+y[k]]==0 and gnl[i+x[k]][j+y[k]]!=0:
            gnh[i+x[k]][j+y[k]]=1
            traverse(i+x[k], j+y[k])
 
for i in range(1, width-1):
    for j in range(1, height-1):
        if gnh[i][j]:
            gnh[i][j]=1
            traverse(i, j)

# %%
plt.imshow( gnh )
plt.gray()
plt.show()
figure()
plt.imshow( img )
