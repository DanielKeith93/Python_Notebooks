# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fs = 20000.0
lowcut = 10000.0
T = 0.018
nsamples = T * fs
from scipy.signal import bessel, lfilter


def bessel_bandpass(lowcut,fs, order=6):
    nyq = 0.5 * fs
    low = lowcut / nyq
    b, a = bessel(order, low, btype='low')
    return b, a


def bessel_bandpass_filter(data, lowcut,fs, order=6):
    b, a = bessel_bandpass(lowcut,fs, order=order)
    y = lfilter(b, a, data)
    return y

def bandpass_analog( lowcut , order ):
    b, a = bessel( order, 2 * pi * lowcut, btype = 'low', analog = True )
    return b, a

def filter_analog( data, lowcut, order ):
    b, a = bandpass_analog( lowcut, order )
    y = lfilter( b, a, data )
    return y

# %%
bessel?

# %%
#define parameters
N_0 = 0.37
N_1 = 1 - N_0
deltat = 0.018 #s, taken from spin to charge optimisation
t_down_in = 0.0039
t_up_out = 0.0069 #Taken from experimental data.
deltaI = 32 * 10 ** - 12 #A
points = nsamples
time = linspace( 0, deltat, points )
a_n = 71 * 10 ** - 15 #A / ( ( Hz ) ^ ( 1 / 2 ) ) #Have to multiply spectral density by a bandwidth.
f_c = 300 #Hz, cut off frequency, also used as the bandwidth
A_n = a_n * ( f_c )

# %%
x = random.normal( 0, A_n, points )

# %%
x = random.normal( 0, A_n, points )
figure()
plot(time,x)
y = bessel_bandpass_filter(x, lowcut, fs, order=6)
figure()
plot(time, y)
xlabel('time (seconds)')
grid(True)
axis('tight')
legend(loc='upper left')

# %%
from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=6):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

if __name__ == "__main__":
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.signal import freqz  
    # Sample rate and desired cutoff frequencies (in Hz).
    fs = 1000000
    # Plot the frequency response for a few different orders.
    plt.figure(1)
    plt.clf()
    for order in [2, 4, 6, 8]:
        b, a = butter_bandpass(10000, 20000, fs, order=order)
        w, h = freqz(b, a, worN=2000)#np.logspace(-4, 3, 2000))
        plt.semilogx((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)  
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')

    plt.figure(2)
    plt.clf()
    for order in [2, 4, 6, 8]:
        b, a = butter_bandpass(1000, 2000, fs, order=order)
        w, h = freqz(b, a, worN=2000)#np.logspace(-4, 3, 2000))
        plt.semilogx((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)  
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')

# %%
#filters don't work at lower frequencies

# %%
from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=6):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

if __name__ == "__main__":
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.signal import freqz  
    # Sample rate and desired cutoff frequencies (in Hz).
    fs = 100000
    # Plot the frequency response for a few different orders.
    plt.figure(1)
    plt.clf()
    for order in [2, 4, 6, 8]:
        b, a = butter_bandpass(10000, 20000, fs, order=order)
        w, h = freqz(b, a, worN=2000)#np.logspace(-4, 3, 2000))
        plt.semilogx((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)  
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')

    fs = 10000
    plt.figure(2)
    plt.clf()
    for order in [2, 4, 6, 8]:
        b, a = butter_bandpass(1000, 2000, fs, order=order)
        w, h = freqz(b, a, worN=2000)#np.logspace(-4, 3, 2000))
        plt.semilogx((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)  
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')

# %%
if __name__ == "__main__":
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.signal import freqz  
    # Sample rate and desired cutoff frequencies (in Hz).
    fs = 40000
    # Plot the frequency response for a few different orders.
    plt.figure(1)
    plt.clf()
    for order in [2, 4, 6, 8]:
        b, a = bessel_bandpass(10000, fs, order=order)
        w, h = freqz(b, a, worN=2000) #np.logspace(-4, 3, 2000))
        plt.semilogx((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)  
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')

    fs = 80000
    plt.figure(2)
    plt.clf()
    for order in [2, 4, 6, 8]:
        b, a = bessel_bandpass(10000, fs, order=order)
        w, h = freqz(b, a, worN=2000)#np.logspace(-4, 3, 2000))
        plt.semilogx((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)  
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')

# %%
if __name__ == "__main__":
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.signal import freqz 
    from scipy.signal import freqs

    # Sample rate and desired cutoff frequencies (in Hz).
    fs = 40000
    # Plot the frequency response for a few different orders.
    plt.figure(1)
    plt.clf()
    for order in [2, 4, 6, 8]:
        b, a = bandpass_analog(10000, order=order)
        freqs( b, a )
        w, h = freqs(b, a, worN=np.logspace(0, 5, 1000))
        plt.semilogx(w, 20 * np.log10(abs(h)))

# %%
freqs?
